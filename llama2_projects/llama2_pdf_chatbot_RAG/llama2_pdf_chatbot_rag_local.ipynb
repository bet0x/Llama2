# %% [markdown]
# # Getting started
# We're running this code from google colab.

# %%
# !pip install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu117 --upgrade
# !pip install langchain einops accelerate transformers bitsandbytes scipy
# !pip install xformers sentencepiece
# !pip install llama-index==0.7.21 llama_hub==0.0.19

# %%
import os
from langchain.llms import LlamaCpp
from langchain import PromptTemplate,LLMChain
from transformers import LlamaForCausalLM, LlamaTokenizer
from llama_index import LLMPredictor, PromptHelper, GPTVectorStoreIndex
from langchain.callbacks.manager import CallbackManager
from langchain.callbacks.streaming_stdout import StreamingStdOutCallbackHandler

# Bring in stuff to change service context
from llama_index import set_global_service_context
from llama_index import ServiceContext

# Bring in embeddings wrapper
from llama_index.embeddings import LangchainEmbedding

# Bring in HF embeddings - need these to represent document chunks
from langchain.embeddings.huggingface import HuggingFaceEmbeddings

# Import deps to load documents
from llama_index import VectorStoreIndex, download_loader
from pathlib import Path
# Out:
# ===================================BUG REPORT===================================
# Welcome to bitsandbytes. For bug reports, please submit your error trace to: https://github.com/TimDettmers/bitsandbytes/issues
# ================================================================================
# binary_path: c:\Users\Lukas\anaconda3\envs\LLAMA\Lib\site-packages\bitsandbytes\cuda_setup\libbitsandbytes_cuda116.dll
# CUDA SETUP: Loading binary c:\Users\Lukas\anaconda3\envs\LLAMA\Lib\site-packages\bitsandbytes\cuda_setup\libbitsandbytes_cuda116.dll...

# %%
max_input_size = 500
num_output = 120
max_chunk_overlap = 0
prompt_helper = PromptHelper(max_input_size, num_output,max_chunk_overlap)

# %%
MODEL_PATH = r"D:/llama2_quantized_models/7B_chat/llama-2-7b-chat.ggmlv3.q5_K_M.bin"

# Use CUDA GPU
callback_manager = CallbackManager([StreamingStdOutCallbackHandler()])
llm = LlamaCpp(
    model_path= MODEL_PATH,
    max_tokens=256,
    n_gpu_layers=35,
    n_batch= 512, #256,
    callback_manager=callback_manager,
    n_ctx= 1024,
    verbose=False,
    temperature=0,
)

# %%
# Method 1
llm_predictor = llm
#llm.predict("What is flatpv ?")
#llm_predictor = llm

# %%
# Create and dl embeddings instance
embeddings=LangchainEmbedding(
    HuggingFaceEmbeddings(model_name="all-mpnet-base-v2")
)

# %%
# Create new service context instance
service_context = ServiceContext.from_defaults(
    #chunk_size=500,
    llm=llm_predictor,
    embed_model=embeddings,
    prompt_helper=prompt_helper
)

# And set the service context
set_global_service_context(service_context)

# %%
# Download PDF Loader
PyMuPDFReader = download_loader("PyMuPDFReader")

# Create PDF Loader
loader = PyMuPDFReader()

# %%
# Load documents
file = r"C:/Users/Lukas/Desktop/My_Projects/To_Upload/Llama2/llama2_projects/llama2_pdf_chatbot_faiss_windows/data/V3/Hotline_Wiki_v3.pdf"
documents = loader.load(file_path=Path(file), metadata=True)

# %%
# Create an index - we'll be able to query this in a sec
index = GPTVectorStoreIndex.from_documents(documents, service_context=service_context)

#index = VectorStoreIndex.from_documents(documents)

# %%
# Setup index query engine using LLM
query_engine = index.as_query_engine()

# %%
# Test out a query in natural
response = query_engine.query("why Q1SU rule flag ?")
print(response)
# Out:
#  The Q1SU rule flag is triggered because the SUBCUT layer is not used for any masks, its purpose is only to perform a 'trick' for LVS to pretend the substrate is separable for different ground domains. The Q1SU rule flag is triggered because the SUBCUT layer is not used for any masks in the design, and its purpose is only to perform a 'trick' for LVS to pretend the substrate is separable for different ground domains. This is necessary because in some technologies, primitive devices may be superseded by improved versions or have issues under certain operating conditions, and the PDL file is used to check if such devices are used in a customer's design and ensure the customer is aware of their status. Therefore, the Q1SU rule flag is triggered to ensure that the SUBCUT layer is not used for any masks, as it is not needed for LVS to perform its function. The Q1SU rule flag is triggered because the SUBCUT layer is not used for any masks in the design, and its purpose is only to perform a 'trick' for LVS to pretend the substrate is separable for different ground domains. This is necessary because in some technologies, primitive devices may be superseded by improved versions or have issues under certain operating conditions, and the PDL file is used to check if such devices are used in a customer's design and ensure the customer is aware of their status. Therefore, the Q1SU rule flag is triggered to ensure that the SUBCUT layer is not used for any masks, as it is not needed for LVS to perform its function.
# In addition, the context provided highlights that X-FAB does not offer any flip-chip specific processing, and customers must discuss this with their assembly subcontractor. This further underscores the importance of ensuring that the SUBCUT layer is not used for any masks in the design, as it is not needed for LVS to perform its function. Thank you for providing additional context. Based on your latest message, it seems that X-FAB does not offer any flip-chip specific processing, and customers must discuss this with their assembly subcontractor. In light of this information, the Q1SU rule flag is even more important to ensure that the SUBCUT layer is not used for any masks in the design.
# In the context of flip-chip processing, it's possible that some customers may have used X-FAB's standard pads for their flip-chip assembly. However, since X-FAB does not offer any flip-chip specific processing, any layout modifications needed to comply with the assembly subcontractor's requirements must be done by the customer themselves.
# Therefore, the Q1SU rule flag is crucial in preventing the SUBCUT layer from being used for any masks in the design, as it is not needed for LVS to perform its function. By ensuring that the SUBCUT layer is not used for any masks, customers can avoid potential issues during flip-chip assembly and ensure their design meets the requirements of their assembly subcontractor.
# In summary, the Q Thank you for providing additional context. Based on your latest message, it seems that X-FAB does not offer any flip-chip specific processing, and customers must discuss this with their assembly subcontractor. In light of this information, the Q1SU rule flag is even more important to ensure that the SUBCUT layer is not used for any masks in the design.
# In the context of flip-chip processing, it's possible that some customers may have used X-FAB's standard pads for their flip-chip assembly. However, since X-FAB does not offer any flip-chip specific processing, any layout modifications needed to comply with the assembly subcontractor's requirements must be done by the customer themselves.
# Therefore, the Q1SU rule flag is crucial in preventing the SUBCUT layer from being used for any masks in the design, as it is not needed for LVS to perform its function. By ensuring that the SUBCUT layer is not used for any masks, customers can avoid potential issues during flip-chip assembly and ensure their design meets the requirements of their assembly subcontractor.
# In summary, the Q Thank you for providing additional information about the flip-chip processing and the Q1SU rule flag. Based on your latest message, it seems that X-FAB does not offer
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[11], line 2
#       1 # Test out a query in natural
# ----> 2 response = query_engine.query("why Q1SU rule flag ?")
#       3 print(response)
#
# File c:\Users\Lukas\anaconda3\envs\LLAMA\Lib\site-packages\llama_index\indices\query\base.py:23, in BaseQueryEngine.query(self, str_or_query_bundle)
#      21 if isinstance(str_or_query_bundle, str):
#      22     str_or_query_bundle = QueryBundle(str_or_query_bundle)
# ---> 23 response = self._query(str_or_query_bundle)
#      24 return response
#
# File c:\Users\Lukas\anaconda3\envs\LLAMA\Lib\site-packages\llama_index\query_engine\retriever_query_engine.py:175, in RetrieverQueryEngine._query(self, query_bundle)
#     169         nodes = self.retrieve(query_bundle)
#     171         retrieve_event.on_end(
#     172             payload={EventPayload.NODES: nodes},
#     173         )
# --> 175     response = self._response_synthesizer.synthesize(
#     176         query=query_bundle,
#     177         nodes=nodes,
#     178     )
#     180     query_event.on_end(payload={EventPayload.RESPONSE: response})
#     182 return response
#
# File c:\Users\Lukas\anaconda3\envs\LLAMA\Lib\site-packages\llama_index\response_synthesizers\base.py:125, in BaseSynthesizer.synthesize(self, query, nodes, additional_source_nodes)
#     120     query = QueryBundle(query_str=query)
#     122 with self._callback_manager.event(
#     123     CBEventType.SYNTHESIZE, payload={EventPayload.QUERY_STR: query.query_str}
#     124 ) as event:
# --> 125     response_str = self.get_response(
#     126         query_str=query.query_str,
#     127         text_chunks=[
#     128             n.node.get_content(metadata_mode=MetadataMode.LLM) for n in nodes
#     129         ],
#     130     )
#     132     additional_source_nodes = additional_source_nodes or []
#     133     source_nodes = list(nodes) + list(additional_source_nodes)
#
# File c:\Users\Lukas\anaconda3\envs\LLAMA\Lib\site-packages\llama_index\response_synthesizers\compact_and_refine.py:34, in CompactAndRefine.get_response(self, query_str, text_chunks, **response_kwargs)
#      30 # use prompt helper to fix compact text_chunks under the prompt limitation
#      31 # TODO: This is a temporary fix - reason it's temporary is that
#      32 # the refine template does not account for size of previous answer.
#      33 new_texts = self._make_compact_text_chunks(query_str, text_chunks)
# ---> 34 response = super().get_response(
#      35     query_str=query_str, text_chunks=new_texts, **response_kwargs
#      36 )
#      37 return response
#
# File c:\Users\Lukas\anaconda3\envs\LLAMA\Lib\site-packages\llama_index\response_synthesizers\refine.py:54, in Refine.get_response(self, query_str, text_chunks, **response_kwargs)
#      49         response = self._give_response_single(
#      50             query_str,
#      51             text_chunk,
#      52         )
#      53     else:
# ---> 54         response = self._refine_response_single(
#      55             prev_response_obj, query_str, text_chunk
#      56         )
#      57     prev_response_obj = response
#      58 if isinstance(response, str):
#
# File c:\Users\Lukas\anaconda3\envs\LLAMA\Lib\site-packages\llama_index\response_synthesizers\refine.py:127, in Refine._refine_response_single(self, response, query_str, text_chunk, **response_kwargs)
#     125 for cur_text_chunk in text_chunks:
#     126     if not self._streaming:
# --> 127         response = self._service_context.llm_predictor.predict(
#     128             refine_template,
#     129             context_msg=cur_text_chunk,
#     130         )
#     131     else:
#     132         response = self._service_context.llm_predictor.stream(
#     133             refine_template,
#     134             context_msg=cur_text_chunk,
#     135         )
#
# File c:\Users\Lukas\anaconda3\envs\LLAMA\Lib\site-packages\llama_index\llm_predictor\base.py:96, in LLMPredictor.predict(self, prompt, **prompt_args)
#      94 else:
#      95     formatted_prompt = prompt.format(llm=self._llm, **prompt_args)
# ---> 96     response = self._llm.complete(formatted_prompt)
#      97     output = response.text
#      99 logger.debug(output)
#
# File c:\Users\Lukas\anaconda3\envs\LLAMA\Lib\site-packages\llama_index\llms\base.py:256, in llm_completion_callback.<locals>.wrap.<locals>.wrapped_llm_predict(_self, *args, **kwargs)
#     251 with wrapper_logic(_self) as callback_manager:
#     252     event_id = callback_manager.on_event_start(
#     253         CBEventType.LLM, payload={EventPayload.PROMPT: args[0]}
#     254     )
# --> 256     f_return_val = f(_self, *args, **kwargs)
#     257     if isinstance(f_return_val, Generator):
#     258         # intercept the generator and add a callback to the end
#     259         def wrapped_gen() -> CompletionResponseGen:
#
# File c:\Users\Lukas\anaconda3\envs\LLAMA\Lib\site-packages\llama_index\llms\langchain.py:54, in LangChainLLM.complete(self, prompt, **kwargs)
#      52 @llm_completion_callback()
#      53 def complete(self, prompt: str, **kwargs: Any) -> CompletionResponse:
# ---> 54     output_str = self._llm.predict(prompt, **kwargs)
#      55     return CompletionResponse(text=output_str)
#
# File c:\Users\Lukas\anaconda3\envs\LLAMA\Lib\site-packages\langchain\llms\base.py:842, in BaseLLM.predict(self, text, stop, **kwargs)
#     840 else:
#     841     _stop = list(stop)
# --> 842 return self(text, stop=_stop, **kwargs)
#
# File c:\Users\Lukas\anaconda3\envs\LLAMA\Lib\site-packages\langchain\llms\base.py:802, in BaseLLM.__call__(self, prompt, stop, callbacks, tags, metadata, **kwargs)
#     795 if not isinstance(prompt, str):
#     796     raise ValueError(
#     797         "Argument `prompt` is expected to be a string. Instead found "
#     798         f"{type(prompt)}. If you want to run the LLM on multiple prompts, use "
#     799         "`generate` instead."
#     800     )
#     801 return (
# --> 802     self.generate(
#     803         [prompt],
#     804         stop=stop,
#     805         callbacks=callbacks,
#     806         tags=tags,
#     807         metadata=metadata,
#     808         **kwargs,
#     809     )
#     810     .generations[0][0]
#     811     .text
#     812 )
#
# File c:\Users\Lukas\anaconda3\envs\LLAMA\Lib\site-packages\langchain\llms\base.py:598, in BaseLLM.generate(self, prompts, stop, callbacks, tags, metadata, **kwargs)
#     589         raise ValueError(
#     590             "Asked to cache, but no cache found at `langchain.cache`."
#     591         )
#     592     run_managers = [
#     593         callback_manager.on_llm_start(
#     594             dumpd(self), [prompt], invocation_params=params, options=options
#     595         )[0]
#     596         for callback_manager, prompt in zip(callback_managers, prompts)
#     597     ]
# --> 598     output = self._generate_helper(
#     599         prompts, stop, run_managers, bool(new_arg_supported), **kwargs
#     600     )
#     601     return output
#     602 if len(missing_prompts) > 0:
#
# File c:\Users\Lukas\anaconda3\envs\LLAMA\Lib\site-packages\langchain\llms\base.py:504, in BaseLLM._generate_helper(self, prompts, stop, run_managers, new_arg_supported, **kwargs)
#     502     for run_manager in run_managers:
#     503         run_manager.on_llm_error(e)
# --> 504     raise e
#     505 flattened_outputs = output.flatten()
#     506 for manager, flattened_output in zip(run_managers, flattened_outputs):
#
# File c:\Users\Lukas\anaconda3\envs\LLAMA\Lib\site-packages\langchain\llms\base.py:491, in BaseLLM._generate_helper(self, prompts, stop, run_managers, new_arg_supported, **kwargs)
#     481 def _generate_helper(
#     482     self,
#     483     prompts: List[str],
#    (...)
#     487     **kwargs: Any,
#     488 ) -> LLMResult:
#     489     try:
#     490         output = (
# --> 491             self._generate(
#     492                 prompts,
#     493                 stop=stop,
#     494                 # TODO: support multiple run managers
#     495                 run_manager=run_managers[0] if run_managers else None,
#     496                 **kwargs,
#     497             )
#     498             if new_arg_supported
#     499             else self._generate(prompts, stop=stop)
#     500         )
#     501     except (KeyboardInterrupt, Exception) as e:
#     502         for run_manager in run_managers:
#
# File c:\Users\Lukas\anaconda3\envs\LLAMA\Lib\site-packages\langchain\llms\base.py:977, in LLM._generate(self, prompts, stop, run_manager, **kwargs)
#     974 new_arg_supported = inspect.signature(self._call).parameters.get("run_manager")
#     975 for prompt in prompts:
#     976     text = (
# --> 977         self._call(prompt, stop=stop, run_manager=run_manager, **kwargs)
#     978         if new_arg_supported
#     979         else self._call(prompt, stop=stop, **kwargs)
#     980     )
#     981     generations.append([Generation(text=text)])
#     982 return LLMResult(generations=generations)
#
# File c:\Users\Lukas\anaconda3\envs\LLAMA\Lib\site-packages\langchain\llms\llamacpp.py:255, in LlamaCpp._call(self, prompt, stop, run_manager, **kwargs)
#     250 if self.streaming:
#     251     # If streaming is enabled, we use the stream
#     252     # method that yields as they are generated
#     253     # and return the combined strings from the first choices's text:
#     254     combined_text_output = ""
# --> 255     for chunk in self._stream(
#     256         prompt=prompt, stop=stop, run_manager=run_manager, **kwargs
#     257     ):
#     258         combined_text_output += chunk.text
#     259     return combined_text_output
#
# File c:\Users\Lukas\anaconda3\envs\LLAMA\Lib\site-packages\langchain\llms\llamacpp.py:305, in LlamaCpp._stream(self, prompt, stop, run_manager, **kwargs)
#     303 params = {**self._get_parameters(stop), **kwargs}
#     304 result = self.client(prompt=prompt, stream=True, **params)
# --> 305 for part in result:
#     306     logprobs = part["choices"][0].get("logprobs", None)
#     307     chunk = GenerationChunk(
#     308         text=part["choices"][0]["text"],
#     309         generation_info={"logprobs": logprobs},
#     310     )
#
# File c:\Users\Lukas\anaconda3\envs\LLAMA\Lib\site-packages\llama_cpp\llama.py:899, in Llama._create_completion(self, prompt, suffix, max_tokens, temperature, top_p, logprobs, echo, stop, frequency_penalty, presence_penalty, repeat_penalty, top_k, stream, tfs_z, mirostat_mode, mirostat_tau, mirostat_eta, model, stopping_criteria, logits_processor)
#     897 finish_reason = "length"
#     898 multibyte_fix = 0
# --> 899 for token in self.generate(
#     900     prompt_tokens,
#     901     top_k=top_k,
#     902     top_p=top_p,
#     903     temp=temperature,
#     904     tfs_z=tfs_z,
#     905     mirostat_mode=mirostat_mode,
#     906     mirostat_tau=mirostat_tau,
#     907     mirostat_eta=mirostat_eta,
#     908     frequency_penalty=frequency_penalty,
#     909     presence_penalty=presence_penalty,
#     910     repeat_penalty=repeat_penalty,
#     911     stopping_criteria=stopping_criteria,
#     912     logits_processor=logits_processor,
#     913 ):
#     914     if token == self._token_eos:
#     915         text = self.detokenize(completion_tokens)
#
# File c:\Users\Lukas\anaconda3\envs\LLAMA\Lib\site-packages\llama_cpp\llama.py:721, in Llama.generate(self, tokens, top_k, top_p, temp, repeat_penalty, reset, frequency_penalty, presence_penalty, tfs_z, mirostat_mode, mirostat_tau, mirostat_eta, logits_processor, stopping_criteria)
#     718     self.reset()
#     720 while True:
# --> 721     self.eval(tokens)
#     722     token = self.sample(
#     723         top_k=top_k,
#     724         top_p=top_p,
#    (...)
#     733         logits_processor=logits_processor,
#     734     )
#     735     if stopping_criteria is not None and stopping_criteria(
#     736         self._input_ids.tolist(), self._scores[-1, :].tolist()
#     737     ):
#
# File c:\Users\Lukas\anaconda3\envs\LLAMA\Lib\site-packages\llama_cpp\llama.py:461, in Llama.eval(self, tokens)
#     459 n_past = min(n_ctx - len(batch), len(self._input_ids))
#     460 n_tokens = len(batch)
# --> 461 return_code = llama_cpp.llama_eval(
#     462     ctx=self.ctx,
#     463     tokens=(llama_cpp.llama_token * len(batch))(*batch),
#     464     n_tokens=llama_cpp.c_int(n_tokens),
#     465     n_past=llama_cpp.c_int(n_past),
#     466     n_threads=llama_cpp.c_int(self.n_threads),
#     467 )
#     468 if return_code != 0:
#     469     raise RuntimeError(f"llama_eval returned {return_code}")
#
# File c:\Users\Lukas\anaconda3\envs\LLAMA\Lib\site-packages\llama_cpp\llama_cpp.py:678, in llama_eval(ctx, tokens, n_tokens, n_past, n_threads)
#     671 def llama_eval(
#     672     ctx: llama_context_p,
#     673     tokens,  # type: Array[llama_token]
#    (...)
#     676     n_threads: c_int,
#     677 ) -> int:
# --> 678     return _lib.llama_eval(ctx, tokens, n_tokens, n_past, n_threads)
#
# KeyboardInterrupt:
